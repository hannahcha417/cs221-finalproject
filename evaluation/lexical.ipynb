# %%
import pandas as pd
from collections import Counter, defaultdict
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hanna\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
import re
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

stop_words = set(stopwords.words("english"))

def clean(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", "", text)
    words = text.split()
    return [w for w in words if w not in stop_words]

# Load data
df = pd.read_json("../data/experiment.jsonl", lines=True)

# Collect word counts by race
word_counts = defaultdict(Counter)
total_words = Counter()

for _, row in df.iterrows():
    race = row["race"]
    words = clean(row["response"])
    word_counts[race].update(words)
    total_words.update(words)

# Combine other races for comparison
race_terms = {
    "black", "white", "asian", "hispanic", "native", "american",
    "pacific", "islander", "hawaiian", "indianalaska", "african",
    "hawaiianpacific", "nativeamerican", "caucasian", "americanalaska", "alaska"
}

def log_odds_ratio_filtered(target_race, word_counts, alpha=0.01, top_n=20):
    all_words = set(w for c in word_counts.values() for w in c)
    target_counts = word_counts[target_race]
    other_counts = Counter()
    for race, counts in word_counts.items():
        if race != target_race:
            other_counts.update(counts)

    results = []
    for word in all_words:
        if word in race_terms:
            continue  # skip racial terms

        a = target_counts[word] + alpha
        b = sum(target_counts.values()) + alpha * len(all_words)
        c = other_counts[word] + alpha
        d = sum(other_counts.values()) + alpha * len(all_words)

        log_odds = np.log((a / (b - a)) / (c / (d - c)))

        if log_odds > 0:  # only keep positive distinctive words
            results.append((word, log_odds, target_counts[word]))

    return sorted(results, key=lambda x: -x[1])[:top_n]  # top-N only

for race in word_counts:
    print(f"\nWords most overrepresented in {race} (excluding race terms):")
    for word, logodds, count in log_odds_ratio_filtered(race, word_counts):
        print(f"{word:<15} log-odds: {logodds:.3f}  count: {count}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hanna\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Words most overrepresented in Black (excluding race terms):
# coiled          log-odds: 9.734  z: 0.97  p: 0.3304  count: 33
# closelycropped  log-odds: 9.734  z: 0.97  p: 0.3304  count: 33
# curled          log-odds: 8.539  z: 0.85  p: 0.3934  count: 10
# wellmaintained  log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# sped            log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# ongoing         log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# concerns        log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# shortcropped    log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# confidence      log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# jumbled         log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# concealment     log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# inch            log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# deep            log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# panic           log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# stepping        log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# violence        log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# mediumdark      log-odds: 6.933  z: 0.69  p: 0.4892  count: 2
# piece           log-odds: 6.245  z: 0.62  p: 0.5343  count: 1
# identify        log-odds: 6.245  z: 0.62  p: 0.5343  count: 1
# remained        log-odds: 6.245  z: 0.62  p: 0.5343  count: 1
#
# Words most overrepresented in White (excluding race terms):
# blond           log-odds: 8.633  z: 0.86  p: 0.3882  count: 11
# sandy           log-odds: 7.845  z: 0.78  p: 0.4332  count: 5
# crime           log-odds: 7.336  z: 0.73  p: 0.4640  count: 3
# grab            log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# clutched        log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# secondstory     log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# nature          log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# intently        log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# trembling       log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# control         log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# demand          log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# understand      log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# parts           log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# hazel           log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# lowering        log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# clumsy          log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# blonde          log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# examined        log-odds: 6.932  z: 0.69  p: 0.4893  count: 2
# locating        log-odds: 6.243  z: 0.62  p: 0.5344  count: 1
# stash           log-odds: 6.243  z: 0.62  p: 0.5344  count: 1
#
# Words most overrepresented in Hispanic (excluding race terms):
# turn            log-odds: 6.976  z: 0.70  p: 0.4865  count: 2
# waist           log-odds: 6.976  z: 0.70  p: 0.4865  count: 2
# generally       log-odds: 6.976  z: 0.70  p: 0.4865  count: 2
# retreated       log-odds: 6.976  z: 0.70  p: 0.4865  count: 2
# instead         log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# safely          log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# mediumtoned     log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# muttered        log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# enforcements    log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# squinting       log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# hurrying        log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# talked          log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# weaponpossibly  log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# included        log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# periods         log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# vertically      log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# thereafter      log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# unnoticed       log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# convenience     log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
# handgunsteadily log-odds: 6.288  z: 0.63  p: 0.5315  count: 1
#
# Words most overrepresented in Asian (excluding race terms):
# combed          log-odds: 8.288  z: 0.83  p: 0.4075  count: 8
# flat            log-odds: 7.309  z: 0.73  p: 0.4656  count: 3
# young           log-odds: 7.309  z: 0.73  p: 0.4656  count: 3
# efforts         log-odds: 7.309  z: 0.73  p: 0.4656  count: 3
# relatively      log-odds: 7.309  z: 0.73  p: 0.4656  count: 3
# known           log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# jogger          log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# scalp           log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# heard           log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# steering        log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# climb           log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# rd              log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# persistently    log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# persistent      log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# blending        log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# intersection    log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# intimidate      log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# wheel           log-odds: 6.905  z: 0.69  p: 0.4909  count: 2
# damage          log-odds: 6.217  z: 0.62  p: 0.5361  count: 1
# corner          log-odds: 6.217  z: 0.62  p: 0.5361  count: 1
#
# Words most overrepresented in American Indian/Alaska Native (excluding race terms):
# loose           log-odds: 7.945  z: 0.79  p: 0.4273  count: 6
# ponytail        log-odds: 7.763  z: 0.78  p: 0.4380  count: 5
# weathered       log-odds: 7.541  z: 0.75  p: 0.4514  count: 4
# deepset         log-odds: 7.254  z: 0.72  p: 0.4690  count: 3
# extending       log-odds: 7.254  z: 0.72  p: 0.4690  count: 3
# wornin          log-odds: 7.254  z: 0.72  p: 0.4690  count: 3
# flailing        log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# complied        log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# obscures        log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# typical         log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# pursued         log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# brow            log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# handgunthough   log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# ruddy           log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# ridge           log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# flannel         log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# chinlength      log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# covers          log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# mediumlength    log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
# demonstrated    log-odds: 6.850  z: 0.68  p: 0.4944  count: 2
#
# Words most overrepresented in Native Hawaiian/Pacific Islander (excluding race terms):
# shortsleeved    log-odds: 7.972  z: 0.80  p: 0.4257  count: 6
# floral          log-odds: 7.568  z: 0.76  p: 0.4498  count: 4
# sleeveless      log-odds: 7.568  z: 0.76  p: 0.4498  count: 4
# sandals         log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# dart            log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# distinct        log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# polynesian      log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# fade            log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# depicting       log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# aloha           log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# garbled         log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# positioning     log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# minimize        log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# kitchenstyle    log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# behavioral      log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# tank            log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# watchful        log-odds: 6.877  z: 0.69  p: 0.4927  count: 2
# hue             log-odds: 6.188  z: 0.62  p: 0.5380  count: 1
# weaponappearing log-odds: 6.188  z: 0.62  p: 0.5380  count: 1
# implement       log-odds: 6.188  z: 0.62  p: 0.5380  count: 1

# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
import re
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

stop_words = set(stopwords.words("english"))

# Clean and tokenize function
def clean(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", "", text)
    words = text.split()
    return [w for w in words if w not in stop_words]

# Load data
df = pd.read_json("data/experiment.jsonl", lines=True)

# Count words by (race, category)
group_word_counts = defaultdict(Counter)
total_words = Counter()

for _, row in df.iterrows():
    key = (row["race"], row["category"])
    words = clean(row["response"])
    group_word_counts[key].update(words)
    total_words.update(words)

# Race terms to exclude from log-odds analysis
race_terms = {
    "black", "white", "asian", "hispanic", "native", "american",
    "pacific", "islander", "hawaiian", "indianalaska", "african",
    "hawaiianpacific", "nativeamerican", "caucasian", "americanalaska", "alaska"
}

# Log-odds ratio calculation across (race, category) groups
def log_odds_by_group(target_key, word_counts, alpha=0.01, top_n=15):
    all_words = set(w for c in word_counts.values() for w in c)
    target_counts = word_counts[target_key]
    other_counts = Counter()
    for group_key, counts in word_counts.items():
        if group_key != target_key:
            other_counts.update(counts)

    results = []
    for word in all_words:
        if word in race_terms:
            continue

        a = target_counts[word] + alpha
        b = sum(target_counts.values()) + alpha * len(all_words)
        c = other_counts[word] + alpha
        d = sum(other_counts.values()) + alpha * len(all_words)

        log_odds = np.log((a / (b - a)) / (c / (d - c)))

        if log_odds > 0:
            results.append((word, log_odds, target_counts[word]))

    return sorted(results, key=lambda x: -x[1])[:top_n]

# Run for each (race, category)
for group_key in group_word_counts:
    race, category = group_key
    print(f"\n Most distinctive words for RACE: {race} | CATEGORY: {category}")
    for word, logodds, count in log_odds_by_group(group_key, group_word_counts):
        print(f"{word:<15} log-odds: {logodds:.3f}  count: {count}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hanna\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#  Most distinctive words for RACE: Black | CATEGORY: Violent Offense
# mediumdark      log-odds: 8.161  count: 2
# deep            log-odds: 8.161  count: 2
# inch            log-odds: 8.161  count: 2
# confidence      log-odds: 8.161  count: 2
# ongoing         log-odds: 8.161  count: 2
# seriousness     log-odds: 7.473  count: 1
# conditions      log-odds: 7.473  count: 1
# younger         log-odds: 7.473  count: 1
# jostle          log-odds: 7.473  count: 1
# hedisplayed     log-odds: 7.473  count: 1
# traveling       log-odds: 7.473  count: 1
# committed       log-odds: 7.473  count: 1
# identify        log-odds: 7.473  count: 1
# shift           log-odds: 7.473  count: 1
# aims            log-odds: 7.473  count: 1
#
#  Most distinctive words for RACE: White | CATEGORY: Violent Offense
# lowering        log-odds: 8.140  count: 2
# demand          log-odds: 8.140  count: 2
# hazel           log-odds: 8.140  count: 2
# stab            log-odds: 7.451  count: 1
# upward          log-odds: 7.451  count: 1
# lip             log-odds: 7.451  count: 1
# warning         log-odds: 7.451  count: 1
# interacted      log-odds: 7.451  count: 1
# masked          log-odds: 7.451  count: 1
# said            log-odds: 7.451  count: 1
# unavailable     log-odds: 7.451  count: 1
# flurry          log-odds: 7.451  count: 1
# launched        log-odds: 7.451  count: 1
# perimeter       log-odds: 7.451  count: 1
# unnatural       log-odds: 7.451  count: 1
#
#  Most distinctive words for RACE: Hispanic | CATEGORY: Violent Offense
# wrung           log-odds: 7.508  count: 1
# bleeding        log-odds: 7.508  count: 1
# address         log-odds: 7.508  count: 1
# wound           log-odds: 7.508  count: 1
# unsecured       log-odds: 7.508  count: 1
# longsleeved     log-odds: 7.508  count: 1
# stylized        log-odds: 7.508  count: 1
# arrival         log-odds: 7.508  count: 1
# intended        log-odds: 7.508  count: 1
# heightening     log-odds: 7.508  count: 1
# contents        log-odds: 7.508  count: 1
# duffle          log-odds: 7.508  count: 1
# glint           log-odds: 7.508  count: 1
# registers       log-odds: 7.508  count: 1
# woodbridge      log-odds: 7.508  count: 1
#
#  Most distinctive words for RACE: Asian | CATEGORY: Violent Offense
# scalp           log-odds: 8.111  count: 2
# intimidate      log-odds: 8.111  count: 2
# mobile          log-odds: 7.423  count: 1
# block           log-odds: 7.423  count: 1
# hindered        log-odds: 7.423  count: 1
# desperation     log-odds: 7.423  count: 1
# theftrelated    log-odds: 7.423  count: 1
# witness         log-odds: 7.423  count: 1
# widened         log-odds: 7.423  count: 1
# rehearsed       log-odds: 7.423  count: 1
# surveil         log-odds: 7.423  count: 1
# sweatshirts     log-odds: 7.423  count: 1
# threw           log-odds: 7.423  count: 1
# intensely       log-odds: 7.423  count: 1
# rage            log-odds: 7.423  count: 1
#
#  Most distinctive words for RACE: American Indian/Alaska Native | CATEGORY: Violent Offense
# chinlength      log-odds: 8.077  count: 2
# covers          log-odds: 8.077  count: 2
# flailing        log-odds: 8.077  count: 2
# pocketknife     log-odds: 8.077  count: 2
# handgunthough   log-odds: 8.077  count: 2
# pursued         log-odds: 8.077  count: 2
# wolf            log-odds: 7.389  count: 1
# shirtless       log-odds: 7.389  count: 1
# militarystyle   log-odds: 7.389  count: 1
# filled          log-odds: 7.389  count: 1
# harmed          log-odds: 7.389  count: 1
# shaggy          log-odds: 7.389  count: 1
# potentially     log-odds: 7.389  count: 1
# shield          log-odds: 7.389  count: 1
# received        log-odds: 7.389  count: 1
#
#  Most distinctive words for RACE: Native Hawaiian/Pacific Islander | CATEGORY: Violent Offense
# polynesian      log-odds: 8.106  count: 2
# kitchenstyle    log-odds: 8.106  count: 2
# row             log-odds: 7.417  count: 1
# monotone        log-odds: 7.417  count: 1
# sightings       log-odds: 7.417  count: 1
# units           log-odds: 7.417  count: 1
# ordered         log-odds: 7.417  count: 1
# routes          log-odds: 7.417  count: 1
# freckles        log-odds: 7.417  count: 1
# coverings       log-odds: 7.417  count: 1
# tote            log-odds: 7.417  count: 1
# demonstrating   log-odds: 7.417  count: 1
# camouflage      log-odds: 7.417  count: 1
# hold            log-odds: 7.417  count: 1
# hue             log-odds: 7.417  count: 1
#
#  Most distinctive words for RACE: Black | CATEGORY: Property Offense
# sped            log-odds: 8.145  count: 2
# two             log-odds: 7.456  count: 1
# slouched        log-odds: 7.456  count: 1
# hasten          log-odds: 7.456  count: 1
# pursuers        log-odds: 7.456  count: 1
# eastern         log-odds: 7.456  count: 1
# quite           log-odds: 7.456  count: 1
# relied          log-odds: 7.456  count: 1
# cannot          log-odds: 7.456  count: 1
# accompanying    log-odds: 7.456  count: 1
# lincoln         log-odds: 7.456  count: 1
# stripes         log-odds: 7.456  count: 1
# accessing       log-odds: 7.456  count: 1
# belonging       log-odds: 7.456  count: 1
# exuded          log-odds: 7.456  count: 1
#
#  Most distinctive words for RACE: White | CATEGORY: Property Offense
# clumsy          log-odds: 8.158  count: 2
# grab            log-odds: 8.158  count: 2
# examined        log-odds: 8.158  count: 2
# secondstory     log-odds: 8.158  count: 2
# beside          log-odds: 7.470  count: 1
# locating        log-odds: 7.470  count: 1
# bin             log-odds: 7.470  count: 1
# loitering       log-odds: 7.470  count: 1
# pane            log-odds: 7.470  count: 1
# permission      log-odds: 7.470  count: 1
# risk            log-odds: 7.470  count: 1
# pocketing       log-odds: 7.470  count: 1
# jog             log-odds: 7.470  count: 1
# fiddled         log-odds: 7.470  count: 1
# discarded       log-odds: 7.470  count: 1
#
#  Most distinctive words for RACE: Hispanic | CATEGORY: Property Offense
# retreated       log-odds: 8.208  count: 2
# southern        log-odds: 7.520  count: 1
# dodging         log-odds: 7.520  count: 1
# employed        log-odds: 7.520  count: 1
# handles         log-odds: 7.520  count: 1
# materials       log-odds: 7.520  count: 1
# accustomed      log-odds: 7.520  count: 1
# unnoticed       log-odds: 7.520  count: 1
# sturdy          log-odds: 7.520  count: 1
# trim            log-odds: 7.520  count: 1
# ground          log-odds: 7.520  count: 1
# descended       log-odds: 7.520  count: 1
# steal           log-odds: 7.520  count: 1
# silent          log-odds: 7.520  count: 1
# dumpster        log-odds: 7.520  count: 1
#
#  Most distinctive words for RACE: Asian | CATEGORY: Property Offense
# flat            log-odds: 8.540  count: 3
# climb           log-odds: 8.136  count: 2
# persistent      log-odds: 8.136  count: 2
# associated      log-odds: 7.447  count: 1
# fence           log-odds: 7.447  count: 1
# buzzed          log-odds: 7.447  count: 1
# although        log-odds: 7.447  count: 1
# corner          log-odds: 7.447  count: 1
# wearer          log-odds: 7.447  count: 1
# system          log-odds: 7.447  count: 1
# looks           log-odds: 7.447  count: 1
# neighbors       log-odds: 7.447  count: 1
# commonly        log-odds: 7.447  count: 1
# beanie          log-odds: 7.447  count: 1
# show            log-odds: 7.447  count: 1
#
#  Most distinctive words for RACE: American Indian/Alaska Native | CATEGORY: Property Offense
# discovered      log-odds: 7.411  count: 1
# hang            log-odds: 7.411  count: 1
# indian          log-odds: 7.411  count: 1
# cheekbone       log-odds: 7.411  count: 1
# identifiers     log-odds: 7.411  count: 1
# cast            log-odds: 7.411  count: 1
# brownblack      log-odds: 7.411  count: 1
# ensuring        log-odds: 7.411  count: 1
# prominence      log-odds: 7.411  count: 1
# featuring       log-odds: 7.411  count: 1
# subsequently    log-odds: 7.411  count: 1
# structures      log-odds: 7.411  count: 1
# loaded          log-odds: 7.411  count: 1
# snatch          log-odds: 7.411  count: 1
# sketching       log-odds: 7.411  count: 1
#
#  Most distinctive words for RACE: Native Hawaiian/Pacific Islander | CATEGORY: Property Offense
# minimize        log-odds: 8.106  count: 2
# sprint          log-odds: 7.418  count: 1
# neckline        log-odds: 7.418  count: 1
# tiptoe          log-odds: 7.418  count: 1
# foliage         log-odds: 7.418  count: 1
# confronted      log-odds: 7.418  count: 1
# nimble          log-odds: 7.418  count: 1
# acts            log-odds: 7.418  count: 1
# engage          log-odds: 7.418  count: 1
# seenacting      log-odds: 7.418  count: 1
# caramel         log-odds: 7.418  count: 1
# locations       log-odds: 7.418  count: 1
# whether         log-odds: 7.418  count: 1
# rips            log-odds: 7.418  count: 1
# movementspossibly log-odds: 7.418  count: 1
#
#  Most distinctive words for RACE: Black | CATEGORY: Individual Offense
# concerns        log-odds: 8.150  count: 2
# violence        log-odds: 8.150  count: 2
# jumbled         log-odds: 8.150  count: 2
# stepping        log-odds: 8.150  count: 2
# slouching       log-odds: 7.461  count: 1
# jerking         log-odds: 7.461  count: 1
# distinguish     log-odds: 7.461  count: 1
# hesitating      log-odds: 7.461  count: 1
# shifted         log-odds: 7.461  count: 1
# powder          log-odds: 7.461  count: 1
# repetitions     log-odds: 7.461  count: 1
# required        log-odds: 7.461  count: 1
# whereabouts     log-odds: 7.461  count: 1
# soda            log-odds: 7.461  count: 1
# cease           log-odds: 7.461  count: 1
#
#  Most distinctive words for RACE: White | CATEGORY: Individual Offense
# understand      log-odds: 8.153  count: 2
# nature          log-odds: 8.153  count: 2
# condition       log-odds: 7.464  count: 1
# outdated        log-odds: 7.464  count: 1
# sclera          log-odds: 7.464  count: 1
# crossing        log-odds: 7.464  count: 1
# noises          log-odds: 7.464  count: 1
# paranoid        log-odds: 7.464  count: 1
# passing         log-odds: 7.464  count: 1
# drooping        log-odds: 7.464  count: 1
# glare           log-odds: 7.464  count: 1
# judgment        log-odds: 7.464  count: 1
# stash           log-odds: 7.464  count: 1
# disregarded     log-odds: 7.464  count: 1
# contributed     log-odds: 7.464  count: 1
#
#  Most distinctive words for RACE: Hispanic | CATEGORY: Individual Offense
# turn            log-odds: 8.164  count: 2
# highpitched     log-odds: 7.476  count: 1
# keys            log-odds: 7.476  count: 1
# inquiries       log-odds: 7.476  count: 1
# draw            log-odds: 7.476  count: 1
# chose           log-odds: 7.476  count: 1
# merchandiseinto log-odds: 7.476  count: 1
# haphazard       log-odds: 7.476  count: 1
# selected        log-odds: 7.476  count: 1
# bump            log-odds: 7.476  count: 1
# mediumtone      log-odds: 7.476  count: 1
# distraction     log-odds: 7.476  count: 1
# ranged          log-odds: 7.476  count: 1
# dashboard       log-odds: 7.476  count: 1
# yawning         log-odds: 7.476  count: 1
#
#  Most distinctive words for RACE: Asian | CATEGORY: Individual Offense
# steering        log-odds: 8.134  count: 2
# persistently    log-odds: 8.134  count: 2
# heard           log-odds: 8.134  count: 2
# intersection    log-odds: 8.134  count: 2
# wheel           log-odds: 8.134  count: 2
# meters          log-odds: 7.446  count: 1
# nonresponsive   log-odds: 7.446  count: 1
# aided           log-odds: 7.446  count: 1
# diffuse         log-odds: 7.446  count: 1
# tidy            log-odds: 7.446  count: 1
# clutch          log-odds: 7.446  count: 1
# frisking        log-odds: 7.446  count: 1
# various         log-odds: 7.446  count: 1
# obscure         log-odds: 7.446  count: 1
# rims            log-odds: 7.446  count: 1
#
#  Most distinctive words for RACE: American Indian/Alaska Native | CATEGORY: Individual Offense
# extending       log-odds: 8.463  count: 3
# loosely         log-odds: 8.059  count: 2
# obscures        log-odds: 8.059  count: 2
# eventually      log-odds: 8.059  count: 2
# approximate     log-odds: 8.059  count: 2
# ruddy           log-odds: 8.059  count: 2
# flannel         log-odds: 8.059  count: 2
# forearmone      log-odds: 7.371  count: 1
# summary         log-odds: 7.371  count: 1
# engine          log-odds: 7.371  count: 1
# heed            log-odds: 7.371  count: 1
# eager           log-odds: 7.371  count: 1
# perform         log-odds: 7.371  count: 1
# symbol          log-odds: 7.371  count: 1
# stability       log-odds: 7.371  count: 1
#
#  Most distinctive words for RACE: Native Hawaiian/Pacific Islander | CATEGORY: Individual Offense
# positioning     log-odds: 8.094  count: 2
# dart            log-odds: 8.094  count: 2
# garbled         log-odds: 8.094  count: 2
# sandals         log-odds: 8.094  count: 2
# aloha           log-odds: 8.094  count: 2
# positions       log-odds: 7.406  count: 1
# sways           log-odds: 7.406  count: 1
# closer          log-odds: 7.406  count: 1
# specifically    log-odds: 7.406  count: 1
# muttering       log-odds: 7.406  count: 1
# coconut         log-odds: 7.406  count: 1
# greenishbrown   log-odds: 7.406  count: 1
# outbursts       log-odds: 7.406  count: 1
# chatty          log-odds: 7.406  count: 1
# normal          log-odds: 7.406  count: 1

# %%
# Lexical Analysis for Baseline

import pandas as pd
from collections import Counter
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

# Load baseline dataset
df = pd.read_json("data/baseline.jsonl", lines=True)

# Basic tokenizer
def clean(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", "", text)  # remove punctuation
    words = text.split()
    return [w for w in words if w not in stop_words]

# 1. Top 20 most common words overall
all_words = []
for text in df["response"]:
    all_words.extend(clean(text))

overall_counter = Counter(all_words)
print("\n Top 20 Most Frequent Words Overall:")
for word, count in overall_counter.most_common(20):
    print(f"{word:<15} {count}")

# 2. Top 15 words per category
print("\n Top 15 Most Frequent Words by Category:")
for category in df["category"].unique():
    cat_words = []
    for text in df[df["category"] == category]["response"]:
        cat_words.extend(clean(text))
    cat_counter = Counter(cat_words)
    print(f"\n🟦 Category: {category}")
    for word, count in cat_counter.most_common(15):
        print(f"{word:<15} {count}")
# Out:
#  Top 20 Most Frequent Words Overall:
# suspect         557
# dark            447
# black           260
# approximately   255
# hair            244
# build           239
# jeans           239
# male            235
# wearing         234
# short           233
# tall            223
# brown           222
# medium          214
# appeared        209
# hoodie          188
# sneakers        182
# around          159
# appears         148
# incident        144
# description     135
#
#  Top 15 Most Frequent Words by Category:
#
# 🟦 Category: Violent Offense
# suspect         204
# dark            157
# black           106
# approximately   82
# build           80
# jeans           80
# medium          79
# wearing         79
# short           77
# hair            77
# male            76
# tall            76
# incident        76
# appeared        73
# brown           70
#
# 🟦 Category: Property Offense
# suspect         197
# dark            153
# black           102
# approximately   85
# wearing         85
# hair            83
# short           82
# jeans           80
# male            79
# build           79
# brown           74
# medium          73
# tall            72
# sneakers        67
# around          67
#
# 🟦 Category: Individual Offense
# suspect         156
# dark            137
# approximately   88
# hair            84
# male            80
# build           80
# jeans           79
# brown           78
# tall            75
# short           74
# appeared        74
# wearing         70
# hoodie          64
# medium          62
# around          60
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hanna\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
